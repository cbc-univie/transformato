# %%
import transformato
import sys, os
import logging
import shutil
import pathlib
from transformato import load_config_yaml, SystemStructure, ProposeMutationRoute, IntermediateStateFactory, FreeEnergyCalculator
import parmed as pm
import copy
import numpy as np
# read in specific topology with parameters
import subprocess

from transformato import FreeEnergyCalculator
conf = '../config/ethane-methanol-solvation-free-energy.yaml'
configuration = load_config_yaml(config=conf,
                                 input_dir='/home/mwieder/Work/Projects/transformato-systems/', 
                                 output_dir='/data/shared/projects/transformato-systems/production/cc/')

# load systems
s1 = SystemStructure(configuration, 'structure1')
s2 = SystemStructure(configuration, 'structure2')
a = ProposeMutationRoute(s1, s2)


# generate mutation route
mutation_list = a.generate_mutations_to_common_core_for_mol1(
    nr_of_steps_for_el=2, nr_of_steps_for_bonded_parameters=2)
# write intermediate states for systems
i = IntermediateStateFactory(system=s1, mutation_list=mutation_list, configuration=configuration)
i.generate_intermediate_states()
paths = pathlib.Path(i.path).glob('**/*.sh')
for path in sorted(paths):
    run_dir = path.parent
    print(f"Start sampling for: {path}")
    print(f"In directory: {run_dir}")
    try:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True, capture_output=True, text=True)
    except TypeError:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True,
                             stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    #print(exe.stdout)
    print('Capture stderr')
    print(exe.stderr)

# generate mutation route
mutation_list = a.generate_mutations_to_common_core_for_mol2(nr_of_steps_for_el=2)
# write intermediate states
i = IntermediateStateFactory(system=s2, mutation_list=mutation_list, configuration=configuration)
i.generate_intermediate_states()

paths = pathlib.Path(i.path).glob('**/*.sh')
for path in sorted(paths):
    run_dir = path.parent
    print(f"Start sampling for: {path}")
    print(f"In directory: {run_dir}")
    try:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True, capture_output=True, text=True)
    except TypeError:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True,
                             stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    #print(exe.stdout)
    print('Capture stderr')
    print(exe.stderr)
# Out:
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/transformato-0.0.0+140.g7128b26-py3.6.egg/transformato/utils.py:21: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   settingsMap = yaml.load(stream)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:905: UserWarning: LONEPAIR type COLINEAR not supported; only BISEctor and RELAtive supported
#   'RELAtive supported' % words[1])
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:832: UserWarning: No charge for WEI3
#   warnings.warn('No charge for %s' % resname)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:867: UserWarning: WARNING: Ignoring "DELETE ACCE NE2" because entity type ACCE not used.
#   'used.' % (line.strip(), entity_type))
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:511: ParameterWarning: Replacing angle ('NH2', 'CT2', 'CD'), <AngleType; k=50.000, theteq=107.000> with <AngleType; k=52.000, theteq=108.000>
#   (key, self.angle_types[key], angle_type), ParameterWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/lig/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/lig.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/lig/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:511: ParameterWarning: Replacing angle ('NH2', 'CT2', 'CD'), <AngleType; k=50.000, theteq=107.000> with <AngleType; k=52.000, theteq=108.000>
#   (key, self.angle_types[key], angle_type), ParameterWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/UNK.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/unk.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/unk/unk.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/unk.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/UNK.sdf
# [mutate.py:96 - _calculate_common_core()] Mol in SMILES format: [H]C([H])([H])C([H])([H])[H].
# [mutate.py:96 - _calculate_common_core()] Mol in SMILES format: [H]OC([H])([H])[H].
# [mutate.py:104 - _calculate_common_core()] Substructure match: [#6](-[#1])(-[#1])-[#1]
# [mutate.py:110 - _calculate_common_core()] Substructere match idx: (0, 2, 3, 4)
# [mutate.py:113 - _calculate_common_core()] Substructere match idx: (0, 2, 3, 4)
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:1 Element:C
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:5 Element:H
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:6 Element:H
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:7 Element:H
# [mutate.py:600 - __init__()] Rapid charge change detected. Proceed with caution.
# [mutate.py:237 - _transform_common_core()] Charges at commen core need to be transformed
# [mutate.py:600 - __init__()] Rapid charge change detected. Proceed with caution.
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom O [1]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: -0.65
# [mutate.py:686 - mutate()] New charge: -0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: 0.42
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -0.23000000000000004
# [mutate.py:618 - _compensate_charge()] -0.05750000000000001
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:73 - generate_intermediate_states()] #########################################
# [state.py:74 - generate_intermediate_states()] #########################################
# [state.py:75 - generate_intermediate_states()] Preparing for a total of 7 mutation steps
# [state.py:76 - generate_intermediate_states()] Writing endstate
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 0
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst1
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst1
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst2
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst2
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.5
# [mutate.py:683 - mutate()] Scale charge on <Atom C2 [1]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: -0.27
# [mutate.py:686 - mutate()] New charge: -0.135
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -1.3877787807814457e-17
# [mutate.py:618 - _compensate_charge()] -3.469446951953614e-18
# [mutate.py:619 - _compensate_charge()] ##############
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.5
# [mutate.py:683 - mutate()] Scale charge on <Atom C2 [1]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: -0.27
# [mutate.py:686 - mutate()] New charge: -0.135
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -1.3877787807814457e-17
# [mutate.py:618 - _compensate_charge()] -3.469446951953614e-18
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 2
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst3
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst3
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom C2 [1]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: -0.27
# [mutate.py:686 - mutate()] New charge: -0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -1.3877787807814457e-17
# [mutate.py:618 - _compensate_charge()] -3.469446951953614e-18
# [mutate.py:619 - _compensate_charge()] ##############
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom C2 [1]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: -0.27
# [mutate.py:686 - mutate()] New charge: -0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -1.3877787807814457e-17
# [mutate.py:618 - _compensate_charge()] -3.469446951953614e-18
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst4
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst4
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [5, 6, 7]
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [5, 6, 7]
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst5
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst5
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [1]
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [1]
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst6
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst6
# [mutate.py:558 - mutate()]  -- Charge parameters from cc1 are transformed to cc2.
# [mutate.py:559 - mutate()] Scaling factor:0.5
# [mutate.py:558 - mutate()]  -- Charge parameters from cc1 are transformed to cc2.
# [mutate.py:559 - mutate()] Scaling factor:0.5
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 2
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst7
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst7
# [mutate.py:558 - mutate()]  -- Charge parameters from cc1 are transformed to cc2.
# [mutate.py:559 - mutate()] Scaling factor:1.0
# [mutate.py:558 - mutate()]  -- Charge parameters from cc1 are transformed to cc2.
# [mutate.py:559 - mutate()] Scaling factor:1.0
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst1/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst1
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst2/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst2
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst3/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst3
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst4/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst4
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst5/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst5
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst6/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst6
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst7/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/ethane/intst7
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:1 Element:O
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:5 Element:H
# [mutate.py:600 - __init__()] Rapid charge change detected. Proceed with caution.
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# [state.py:73 - generate_intermediate_states()] #########################################
# [state.py:74 - generate_intermediate_states()] #########################################
# [state.py:75 - generate_intermediate_states()] Preparing for a total of 5 mutation steps
# [state.py:76 - generate_intermediate_states()] Writing endstate
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 0
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst1
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst1
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst2
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst2
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.5
# [mutate.py:683 - mutate()] Scale charge on <Atom O [1]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: -0.65
# [mutate.py:686 - mutate()] New charge: -0.325
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: 0.42
# [mutate.py:686 - mutate()] New charge: 0.21
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -0.11500000000000002
# [mutate.py:618 - _compensate_charge()] -0.028750000000000005
# [mutate.py:619 - _compensate_charge()] ##############
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.5
# [mutate.py:683 - mutate()] Scale charge on <Atom O [1]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: -0.65
# [mutate.py:686 - mutate()] New charge: -0.325
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: 0.42
# [mutate.py:686 - mutate()] New charge: 0.21
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -0.11500000000000002
# [mutate.py:618 - _compensate_charge()] -0.028750000000000005
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 2
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst3
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst3
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom O [1]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: -0.65
# [mutate.py:686 - mutate()] New charge: -0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: 0.42
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -0.11500000000000002
# [mutate.py:618 - _compensate_charge()] -0.028750000000000005
# [mutate.py:619 - _compensate_charge()] ##############
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom O [1]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: -0.65
# [mutate.py:686 - mutate()] New charge: -0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H4 [5]; In UNK 0>
# [mutate.py:684 - mutate()] Old charge: 0.42
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: -0.11500000000000002
# [mutate.py:618 - _compensate_charge()] -0.028750000000000005
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst4
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst4
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [5]
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [5]
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst5
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst5
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [1]
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [1]
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst1/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst1
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst2/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst2
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst3/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst3
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst4/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst4
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# Start sampling for: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst5/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/methanol/intst5
# [analysis.py:107 - _merge_trajs()] Evaluating 7 states.
#   0%|          | 0/7 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# 100%|██████████| 7/7 [00:00<00:00, 157.07it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 140
#   0%|          | 0/7 [00:00<?, ?it/s]
# Capture stderr
# b'/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/simtk/openmm/app/charmmparameterset.py:373: UserWarning: Replacing dihedral <DihedralType: k=1.3; phase=180.0; per=3> with <DihedralType: k=0.3; phase=180.0; per=3>\n  (dtype, dihedral))\n'
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  14%|█▍        | 1/7 [00:00<00:01,  3.57it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  29%|██▊       | 2/7 [00:00<00:01,  3.75it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  43%|████▎     | 3/7 [00:00<00:01,  3.91it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  57%|█████▋    | 4/7 [00:01<00:01,  2.94it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  71%|███████▏  | 5/7 [00:01<00:00,  3.45it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  86%|████████▌ | 6/7 [00:01<00:00,  3.93it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# 100%|██████████| 7/7 [00:01<00:00,  3.89it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 140
# [analysis.py:200 - calculate_dG_to_common_core()] Saving results in /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results/
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for vacuum.
# 100%|██████████| 140/140 [00:00<00:00, 1939.79it/s]
# 100%|██████████| 140/140 [00:00<00:00, 2520.00it/s]
# 100%|██████████| 140/140 [00:00<00:00, 2179.09it/s]
# 100%|██████████| 140/140 [00:00<00:00, 2427.64it/s]
# 100%|██████████| 140/140 [00:00<00:00, 2460.29it/s]
# 100%|██████████| 140/140 [00:00<00:00, 2491.10it/s]
# 100%|██████████| 140/140 [00:00<00:00, 2128.49it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_ethane_in_vacuum.pickle
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for waterbox.
# 100%|██████████| 140/140 [00:01<00:00, 84.63it/s]
# 100%|██████████| 140/140 [00:01<00:00, 82.65it/s]
# 100%|██████████| 140/140 [00:01<00:00, 84.25it/s]
# 100%|██████████| 140/140 [00:01<00:00, 80.18it/s]
# 100%|██████████| 140/140 [00:01<00:00, 77.79it/s]
# 100%|██████████| 140/140 [00:01<00:00, 94.98it/s]
# 100%|██████████| 140/140 [00:01<00:00, 94.23it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_ethane_in_waterbox.pickle
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy difference: -0.7882206184883529
# Uncertanty: 0.7184809422422909
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# [analysis.py:107 - _merge_trajs()] Evaluating 5 states.
#   0%|          | 0/5 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# 100%|██████████| 5/5 [00:00<00:00, 239.95it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 100
#   0%|          | 0/5 [00:00<?, ?it/s]
# Free energy to common core: -0.7882206184883529 [kT] with uncertanty: 0.7184809422422909 [kT].
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  20%|██        | 1/5 [00:00<00:00,  5.80it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  40%|████      | 2/5 [00:00<00:00,  5.84it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  60%|██████    | 3/5 [00:00<00:00,  5.85it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
#  80%|████████  | 4/5 [00:00<00:00,  5.88it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 20
# 100%|██████████| 5/5 [00:00<00:00,  5.89it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 100
# [analysis.py:200 - calculate_dG_to_common_core()] Saving results in /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results/
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for vacuum.
# 100%|██████████| 100/100 [00:00<00:00, 2807.38it/s]
# 100%|██████████| 100/100 [00:00<00:00, 2895.32it/s]
# 100%|██████████| 100/100 [00:00<00:00, 2896.36it/s]
# 100%|██████████| 100/100 [00:00<00:00, 2951.70it/s]
# 100%|██████████| 100/100 [00:00<00:00, 2896.72it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_methanol_in_vacuum.pickle
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for waterbox.
# 100%|██████████| 100/100 [00:00<00:00, 104.45it/s]
# 100%|██████████| 100/100 [00:00<00:00, 105.26it/s]
# 100%|██████████| 100/100 [00:01<00:00, 81.17it/s]
# 100%|██████████| 100/100 [00:01<00:00, 63.33it/s]
# 100%|██████████| 100/100 [00:01<00:00, 75.87it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_methanol_in_waterbox.pickle
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy difference: -0.7882206184883529
# Uncertanty: 0.7184809422422909
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy to common core: 11.430859583652142 [kT] with uncertanty: 1.038168401542699 [kT].

# %%
f = FreeEnergyCalculator(configuration, 'ethane')
f.load_trajs(thinning=1)
f.calculate_dG_to_common_core()
ddG, dddG = f.end_state_free_energy_difference
print(f"Free energy difference: {ddG}")
print(f"Uncertanty: {dddG}")

f.show_summary()
# Out:
# [analysis.py:107 - _merge_trajs()] Evaluating 7 states.
#   0%|          | 0/7 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# 100%|██████████| 7/7 [00:00<00:00, 139.74it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 672
#   0%|          | 0/7 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  14%|█▍        | 1/7 [00:00<00:01,  3.98it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  29%|██▊       | 2/7 [00:00<00:01,  4.13it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  43%|████▎     | 3/7 [00:00<00:00,  4.24it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  57%|█████▋    | 4/7 [00:00<00:00,  4.32it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  71%|███████▏  | 5/7 [00:01<00:00,  4.66it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  86%|████████▌ | 6/7 [00:01<00:00,  4.98it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# 100%|██████████| 7/7 [00:01<00:00,  4.90it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 672
# [analysis.py:200 - calculate_dG_to_common_core()] Saving results in /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results/
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for vacuum.
# 100%|██████████| 672/672 [00:00<00:00, 2603.86it/s]
# 100%|██████████| 672/672 [00:00<00:00, 2512.04it/s]
# 100%|██████████| 672/672 [00:00<00:00, 2512.22it/s]
# 100%|██████████| 672/672 [00:00<00:00, 2600.67it/s]
# 100%|██████████| 672/672 [00:00<00:00, 2591.08it/s]
# 100%|██████████| 672/672 [00:00<00:00, 2789.46it/s]
# 100%|██████████| 672/672 [00:00<00:00, 2807.66it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_ethane_in_vacuum.pickle
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for waterbox.
# 100%|██████████| 672/672 [00:06<00:00, 97.48it/s]
# 100%|██████████| 672/672 [00:06<00:00, 96.86it/s]
# 100%|██████████| 672/672 [00:07<00:00, 94.94it/s]
# 100%|██████████| 672/672 [00:07<00:00, 92.58it/s]
# 100%|██████████| 672/672 [00:07<00:00, 92.03it/s]
# 100%|██████████| 672/672 [00:06<00:00, 96.41it/s]
# 100%|██████████| 672/672 [00:06<00:00, 97.33it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_ethane_in_waterbox.pickle
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy difference: 0.19504094555232498
# Uncertanty: 0.3016219141877935
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy to common core: 0.19504094555232498 [kT] with uncertanty: 0.3016219141877935 [kT].

# %%
f = FreeEnergyCalculator(configuration, 'methanol')
f.load_trajs(thinning=1)
f.calculate_dG_to_common_core()
print(f"Free energy difference: {ddG}")
print(f"Uncertanty: {dddG}")

f.show_summary()
# Out:
# [analysis.py:107 - _merge_trajs()] Evaluating 5 states.
#   0%|          | 0/5 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# 100%|██████████| 5/5 [00:00<00:00, 161.72it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 480
#   0%|          | 0/5 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  20%|██        | 1/5 [00:00<00:01,  2.14it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  40%|████      | 2/5 [00:00<00:01,  2.54it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  60%|██████    | 3/5 [00:00<00:00,  2.93it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
#  80%|████████  | 4/5 [00:01<00:00,  3.29it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 96
# 100%|██████████| 5/5 [00:01<00:00,  3.87it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 480
# [analysis.py:200 - calculate_dG_to_common_core()] Saving results in /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results/
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for vacuum.
# 100%|██████████| 480/480 [00:00<00:00, 3280.83it/s]
# 100%|██████████| 480/480 [00:00<00:00, 3049.22it/s]
# 100%|██████████| 480/480 [00:00<00:00, 2753.62it/s]
# 100%|██████████| 480/480 [00:00<00:00, 2861.55it/s]
# 100%|██████████| 480/480 [00:00<00:00, 2714.21it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_methanol_in_vacuum.pickle
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for waterbox.
# 100%|██████████| 480/480 [00:05<00:00, 91.03it/s]
# 100%|██████████| 480/480 [00:04<00:00, 96.22it/s]
# 100%|██████████| 480/480 [00:05<00:00, 93.94it/s]
# 100%|██████████| 480/480 [00:05<00:00, 93.94it/s]
# 100%|██████████| 480/480 [00:05<00:00, 94.22it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/cc/ethane-methanol-solvation-free-energy/results//mbar_data_for_methanol_in_waterbox.pickle
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy difference: 0.19504094555232498
# Uncertanty: 0.3016219141877935
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy to common core: 11.867262286826096 [kT] with uncertanty: 0.43697941321797273 [kT].

# %%
ddG(ethan->cc) = 0.195 - 11.867 = -11.672 kT = 6.9 kcal/mol
