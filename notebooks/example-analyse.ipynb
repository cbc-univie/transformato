# %%
from transformato import load_config_yaml, FreeEnergyCalculator, SystemStructure

# %%
configuration = load_config_yaml(config='../config/CE105-CE121.yaml',
                       input_dir='../data/', output_dir='../data/CE105-CE121/')
# Out:
# /home/mwieder/anaconda3/envs/transformato/lib/python3.6/site-packages/transformato-0.0.0+79.gc6a9899-py3.6.egg/transformato/utils.py:17: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   settingsMap = yaml.load(stream)

# %%
#s1 = SystemStructure(configuration, 'structure1')
#s2 = SystemStructure(configuration, 'structure2')
#from transformato.mutate import ProposeMutationRoute
#a = ProposeMutationRoute(s1, s2)

# %%
#SVG(a.show_common_core_on_mol1())

# %%
#SVG(a.show_common_core_on_mol2())

# %%
f= FreeEnergyCalculator(configuration, 'CE105')
f.show_summary()
# Out:
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy to common core: -4.294784899114599 [kT] with uncertanty: 0.14495512910983416 [kT].

# %%
f= FreeEnergyCalculator(configuration, 'CE121')
f.show_summary()
# Out:
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy to common core: -3.733223536315009 [kT] with uncertanty: 0.8818276907886804 [kT].
