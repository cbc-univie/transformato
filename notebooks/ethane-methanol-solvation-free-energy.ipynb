# %%
from transformato import FreeEnergyCalculator

import transformato
import pytest
import sys, os
import logging
import shutil
import pathlib
from transformato import load_config_yaml, SystemStructure, ProposeMutationRoute, IntermediateStateFactory
import parmed as pm
import copy
import numpy as np
# read in specific topology with parameters
from parmed.charmm.parameters import CharmmParameterSet
import subprocess

from transformato import FreeEnergyCalculator
conf = '../config/ethane-methanol-solvation-free-energy.yaml'
configuration = load_config_yaml(config=conf,
                                 input_dir='/home/mwieder/Work/Projects/transformato-systems/', 
                                 output_dir='/data/shared/projects/transformato-systems/production/')

# load systems
print(configuration)
s1 = SystemStructure(configuration, 'structure1')
s2 = SystemStructure(configuration, 'structure2')
a = ProposeMutationRoute(s1, s2)


# manually matching Oxygen (0) with Hydrogen (4) 
a.add_idx_to_common_core_of_mol1(1)
a.add_idx_to_common_core_of_mol2(1)

a.add_idx_to_common_core_of_mol1(5)
a.add_idx_to_common_core_of_mol2(5)


# generate mutation route
mutation_list = a.generate_mutations_to_common_core_for_mol1(
    nr_of_steps_for_el=2, nr_of_steps_for_bonded_parameters=10)
# write intermediate states for systems
i = IntermediateStateFactory(system=s1, mutation_list=mutation_list, configuration=configuration)
i.generate_intermediate_states()
paths = pathlib.Path(i.path).glob('**/*.sh')
for path in sorted(paths):
    run_dir = path.parent
    # because path is object not string
    print(f"Start sampling for: {path}")
    print(f"In directory: {run_dir}")
    try:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True, capture_output=True, text=True)
    except TypeError:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True,
                             stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(exe.stdout)
    print('Capture stderr')
    print(exe.stderr)

# generate mutation route
mutation_list = a.generate_mutations_to_common_core_for_mol2(nr_of_steps_for_el=5)
# write intermediate states
i = IntermediateStateFactory(system=s2, mutation_list=mutation_list, configuration=configuration)
i.generate_intermediate_states()

paths = pathlib.Path(i.path).glob('**/*.sh')
for path in sorted(paths):
    run_dir = path.parent
    # because path is object not string
    print(f"Start sampling for: {path}")
    print(f"In directory: {run_dir}")
    try:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True, capture_output=True, text=True)
    except TypeError:
        exe = subprocess.run(['bash', str(path), str(run_dir)], check=True,
                             stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(exe.stdout)
    print('Capture stderr')
    print(exe.stderr)

f = FreeEnergyCalculator(configuration, 'ethane')
f.load_trajs(thinning=1)
f.calculate_dG_to_common_core()
ddG, dddG = f.end_state_free_energy_difference
print(f"Free energy difference: {ddG}")
print(f"Uncertanty: {dddG}")

f.show_summary()

f = FreeEnergyCalculator(configuration, 'methanol')
f.load_trajs(thinning=1)
f.calculate_dG_to_common_core()
print(f"Free energy difference: {ddG}")
print(f"Uncertanty: {dddG}")

f.show_summary()
# Out:
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/transformato-0.0.0+140.g7128b26-py3.6.egg/transformato/utils.py:21: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   settingsMap = yaml.load(stream)
# {'system': {'structure1': {'name': 'ethane', 'tlc': 'LIG', 'vacuum': {'dirname': 'vacuum', 'psf_file_name': 'step3_charmm2omm', 'crd_file_name': 'step3_charmm2omm', 'rst_file_name': 'step4_equilibration', 'simulation_parameter': 'step5_production.inp', 'intermediate-filename': 'lig_in_vacuum'}, 'waterbox': {'dirname': 'waterbox', 'psf_file_name': 'step3_charmm2omm', 'crd_file_name': 'step3_charmm2omm', 'rst_file_name': 'step4_equilibration', 'simulation_parameter': 'step5_production.inp', 'intermediate-filename': 'lig_in_waterbox'}, 'charmm_gui_dir': '/home/mwieder/Work/Projects/transformato-systems/ethane/'}, 'structure2': {'name': 'methanol', 'tlc': 'UNK', 'vacuum': {'dirname': 'vacuum', 'psf_file_name': 'step3_charmm2omm', 'crd_file_name': 'step3_charmm2omm', 'rst_file_name': 'step4_equilibration', 'simulation_parameter': 'step5_production.inp', 'intermediate-filename': 'lig_in_vacuum'}, 'waterbox': {'dirname': 'waterbox', 'psf_file_name': 'step3_charmm2omm', 'crd_file_name': 'step3_charmm2omm', 'rst_file_name': 'step4_equilibration', 'simulation_parameter': 'step5_production.inp', 'intermediate-filename': 'lig_in_waterbox'}, 'charmm_gui_dir': '/home/mwieder/Work/Projects/transformato-systems/methanol/'}, 'name': 'ethane-methanol-solvation-free-energy'}, 'simulation': {'parameters': {'nstep': 5000000, 'nstdcd': 10000, 'nstout': 10000, 'cons': 'None', 'dt': 0.001}, 'free-energy-type': 'solvation-free-energy'}, 'solvation': {'steps_for_equilibration': 1000}, 'bin_dir': '/data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/transformato-0.0.0+140.g7128b26-py3.6.egg/transformato/bin', 'analysis_dir_base': '/data/shared/projects/transformato-systems/production', 'data_dir_base': '/home/mwieder/Work/Projects/transformato-systems', 'system_dir': '/data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy', 'cluster_dir': '/data/local/ethane-methanol-solvation-free-energy'}
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:905: UserWarning: LONEPAIR type COLINEAR not supported; only BISEctor and RELAtive supported
#   'RELAtive supported' % words[1])
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:832: UserWarning: No charge for WEI3
#   warnings.warn('No charge for %s' % resname)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:867: UserWarning: WARNING: Ignoring "DELETE ACCE NE2" because entity type ACCE not used.
#   'used.' % (line.strip(), entity_type))
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:511: ParameterWarning: Replacing angle ('NH2', 'CT2', 'CD'), <AngleType; k=50.000, theteq=107.000> with <AngleType; k=52.000, theteq=108.000>
#   (key, self.angle_types[key], angle_type), ParameterWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/lig/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/lig.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/lig/LIG.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/ethane/waterbox/LIG/LIG.sdf
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/parameters.py:511: ParameterWarning: Replacing angle ('NH2', 'CT2', 'CD'), <AngleType; k=50.000, theteq=107.000> with <AngleType; k=52.000, theteq=108.000>
#   (key, self.angle_types[key], angle_type), ParameterWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# /data/shared/software/python_env/anaconda3/envs/transformato/lib/python3.6/site-packages/parmed/charmm/psf.py:319: CharmmWarning: Detected PSF molecule section that is WRONG. Resetting molecularity.
#   'Resetting molecularity.', CharmmWarning)
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/UNK.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/unk.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/unk/unk.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/unk.sdf
# [system.py:247 - _generate_rdkit_mol()] SDF file not found: /home/mwieder/Work/Projects/transformato-systems/methanol/waterbox/UNK/UNK.sdf
# [mutate.py:96 - _calculate_common_core()] Mol in SMILES format: [H]C([H])([H])C([H])([H])[H].
# [mutate.py:96 - _calculate_common_core()] Mol in SMILES format: [H]OC([H])([H])[H].
# [mutate.py:104 - _calculate_common_core()] Substructure match: [#6](-[#1])(-[#1])-[#1]
# [mutate.py:110 - _calculate_common_core()] Substructere match idx: (0, 2, 3, 4)
# [mutate.py:113 - _calculate_common_core()] Substructere match idx: (0, 2, 3, 4)
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:6 Element:H
# [mutate.py:260 - _mutate_to_common_core()] Will be decoupled: Idx:7 Element:H
# [mutate.py:600 - __init__()] Rapid charge change detected. Proceed with caution.
# [mutate.py:219 - _transform_common_core()] ###########
# [mutate.py:220 - _transform_common_core()] Atom that needs to be transformed: <Atom C2 [1]; In LIG 0>.
# [mutate.py:221 - _transform_common_core()] Atom type of atom in cc1: CG331.
# [mutate.py:222 - _transform_common_core()] Template atom: <Atom O [1]; In UNK 0>.
# [mutate.py:223 - _transform_common_core()] Atom type of atom in cc2: OG311.
# [mutate.py:219 - _transform_common_core()] ###########
# [mutate.py:220 - _transform_common_core()] Atom that needs to be transformed: <Atom H4 [5]; In LIG 0>.
# [mutate.py:221 - _transform_common_core()] Atom type of atom in cc1: HGA3.
# [mutate.py:222 - _transform_common_core()] Template atom: <Atom H4 [5]; In UNK 0>.
# [mutate.py:223 - _transform_common_core()] Atom type of atom in cc2: HGP1.
# [mutate.py:229 - _transform_common_core()] Bonded parameters need to be transformed for the cc1 topology.
# [mutate.py:600 - __init__()] Rapid charge change detected. Proceed with caution.
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: 0
# [mutate.py:618 - _compensate_charge()] 0.0
# [mutate.py:619 - _compensate_charge()] ##############
# [0, 2, 3, 4, 1]
# [0, 2, 3, 4, 1]
# [0, 2, 3, 4, 1, 5]
# [0, 2, 3, 4, 1, 5]
# [state.py:73 - generate_intermediate_states()] #########################################
# [state.py:74 - generate_intermediate_states()] #########################################
# [state.py:75 - generate_intermediate_states()] Preparing for a total of 14 mutation steps
# [state.py:76 - generate_intermediate_states()] Writing endstate
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 0
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst1
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst1
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst2
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst2
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.5
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: 0.09
# [mutate.py:618 - _compensate_charge()] 0.015
# [mutate.py:619 - _compensate_charge()] ##############
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.5
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.045
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: 0.09
# [mutate.py:618 - _compensate_charge()] 0.015
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 2
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst3
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst3
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: 0.09
# [mutate.py:618 - _compensate_charge()] 0.015
# [mutate.py:619 - _compensate_charge()] ##############
# [mutate.py:677 - mutate()]  -- Charge to zero mutation.
# [mutate.py:678 - mutate()] Scaling factor: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H5 [6]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:683 - mutate()] Scale charge on <Atom H6 [7]; In LIG 0>
# [mutate.py:684 - mutate()] Old charge: 0.09
# [mutate.py:686 - mutate()] New charge: 0.0
# [mutate.py:615 - _compensate_charge()] ##############
# [mutate.py:616 - _compensate_charge()] Charge to compensate: 0.09
# [mutate.py:618 - _compensate_charge()] 0.015
# [mutate.py:619 - _compensate_charge()] ##############
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst4
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst4
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [6, 7]
# [mutate.py:725 - mutate()]  -- Steric interactions to zero mutation.
# [mutate.py:726 - mutate()] Acting on atoms: [6, 7]
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 1
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst5
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst5
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.1
# [mutate.py:582 - _modify_type()] Setting RRR atomtype for atom: <Atom C2 [1]; In LIG 0>.
# [mutate.py:582 - _modify_type()] Setting RRR atomtype for atom: <Atom H4 [5]; In LIG 0>.
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.1
# [mutate.py:582 - _modify_type()] Setting RRR atomtype for atom: <Atom C2 [1]; In LIG 0>.
# [mutate.py:582 - _modify_type()] Setting RRR atomtype for atom: <Atom H4 [5]; In LIG 0>.
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 2
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst6
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst6
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.2
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.2
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 3
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst7
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst7
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.3
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.3
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 4
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst8
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst8
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.4
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.4
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 5
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst9
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst9
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.5
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.5
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 6
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst10
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst10
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.6
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.6
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 7
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst11
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst11
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.7
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.7
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 8
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst12
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst12
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.8
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.8
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 9
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst13
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst13
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.9
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:0.9
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# [state.py:87 - _write_state()] #########################################
# [state.py:88 - _write_state()] #########################################
# [state.py:89 - _write_state()] Current step: 10
# [state.py:474 - _init_intermediate_state_dir()]  - Created directory: - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst14
# [state.py:476 - _init_intermediate_state_dir()]  - Writing in - /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst14
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:1.0
# [mutate.py:563 - mutate()]  -- Charge/Atom/Bond/Angle/Torsion parameters from cc1 are transformed to cc2.
# [mutate.py:564 - mutate()] Scaling factor:1.0
# [state.py:187 - _copy_files()] No restart file found for vacuum -- starting simulation from crd file.
# [state.py:196 - _copy_files()] No crd file found for vacuum -- using parmed system structure to create crd file.
# Start sampling for: /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst1/simulation.sh
# In directory: /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/ethane/intst1

# %%
f = FreeEnergyCalculator(configuration, 'ethane')
f.load_trajs(thinning=1)
f.calculate_dG_to_common_core()
ddG, dddG = f.end_state_free_energy_difference
print(f"Free energy difference: {ddG}")
print(f"Uncertanty: {dddG}")

f.show_summary()
# Out:
# [analysis.py:107 - _merge_trajs()] Evaluating 14 states.
#   0%|          | 0/14 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  43%|████▎     | 6/14 [00:00<00:00, 59.04it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# [analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# 100%|██████████| 14/14 [00:00<00:00, 76.11it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 6720
#   0%|          | 0/14 [00:00<?, ?it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#   7%|▋         | 1/14 [00:00<00:03,  3.61it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  14%|█▍        | 2/14 [00:00<00:03,  3.76it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  21%|██▏       | 3/14 [00:00<00:02,  3.85it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  29%|██▊       | 4/14 [00:01<00:03,  3.05it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  36%|███▌      | 5/14 [00:01<00:02,  3.20it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  43%|████▎     | 6/14 [00:01<00:02,  3.44it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  50%|█████     | 7/14 [00:02<00:01,  3.63it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  57%|█████▋    | 8/14 [00:02<00:01,  3.78it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  64%|██████▍   | 9/14 [00:02<00:01,  4.03it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  71%|███████▏  | 10/14 [00:02<00:00,  4.37it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  79%|███████▊  | 11/14 [00:02<00:00,  4.64it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  86%|████████▌ | 12/14 [00:03<00:00,  4.85it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
#  93%|█████████▎| 13/14 [00:03<00:00,  5.01it/s][analysis.py:125 - _merge_trajs()] Nr of snapshots: 480
# 100%|██████████| 14/14 [00:03<00:00,  4.14it/s]
# [analysis.py:129 - _merge_trajs()] Combined nr of snapshots: 6720
# [analysis.py:200 - calculate_dG_to_common_core()] Saving results in /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/results/
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for vacuum.
# 100%|██████████| 6720/6720 [00:01<00:00, 4372.67it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4203.53it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4483.49it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4565.72it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4499.89it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4546.36it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4532.32it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4546.53it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4504.75it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4533.97it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4568.14it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4387.01it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4209.46it/s]
# 100%|██████████| 6720/6720 [00:01<00:00, 4517.89it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/results//mbar_data_for_ethane_in_vacuum.pickle
# [analysis.py:203 - calculate_dG_to_common_core()] Generating results for waterbox.
# 100%|██████████| 6720/6720 [01:12<00:00, 92.40it/s]
# 100%|██████████| 6720/6720 [01:11<00:00, 93.38it/s]
# 100%|██████████| 6720/6720 [01:08<00:00, 97.71it/s]
# 100%|██████████| 6720/6720 [01:11<00:00, 93.89it/s]
# 100%|██████████| 6720/6720 [01:09<00:00, 96.18it/s]
# 100%|██████████| 6720/6720 [01:09<00:00, 96.95it/s]
# 100%|██████████| 6720/6720 [01:08<00:00, 97.48it/s]
# 100%|██████████| 6720/6720 [01:10<00:00, 95.74it/s]
# 100%|██████████| 6720/6720 [01:10<00:00, 95.20it/s]
# 100%|██████████| 6720/6720 [01:09<00:00, 96.95it/s]
# 100%|██████████| 6720/6720 [01:09<00:00, 96.89it/s]
# 100%|██████████| 6720/6720 [01:10<00:00, 95.63it/s]
# 100%|██████████| 6720/6720 [01:09<00:00, 96.32it/s]
# 100%|██████████| 6720/6720 [01:09<00:00, 96.60it/s]
# [analysis.py:187 - _analyse_results_using_mbar()] Saving results: /data/shared/projects/transformato-systems/production/ethane-methanol-solvation-free-energy/results//mbar_data_for_ethane_in_waterbox.pickle
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy difference: -11.837076528757004
# Uncertanty: 0.22558963150078992
# [legend.py:1282 - _parse_legend_args()] No handles with labels found to put in legend.
# Free energy to common core: -11.837076528757004 [kT] with uncertanty: 0.22558963150078992 [kT].

# %%
-11.83 * 0.593
# Out:
# -7.01519

# %%
0.22* 0.593
# Out:
# 0.13046
